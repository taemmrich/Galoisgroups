# %%
using Pkg
Pkg.add("Plots")

# %%
using Plots

#p=1/2, k=1000
x=2:25
y=[0.15,0.113,0.106,0.158,0.202,0.257,0.341,0.454,0.525,0.665,0.749,0.848,0.888,0.921,0.951,0.983,0.986,0.995,0.999,0.999,1.0,1.0,1.0,1.0]

plot(x,y,
    seriestype=:scatter;
    xticks=(1:25),
    ylim=(0,1.05),
    titel="probability of random matrices",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=1/2",
    legend=false,
    color=:black
)

#p=4/n, k=1000

yy=[0,0,0,0.095,0.192,0.28,0.385,0.386,0.429,0.44,0.462,0.408,0.455,0.431,0.418,0.433,0.458,0.434,0.398,0.354,0.374,0.394,0.359,0.35]
plot!(x,yy,
    seriestype=:scatter;
    xticks=(1:25),
    ylim=(0,1.05),
    titel="probability of random matrices",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=4/n",
    legend=false,
    color=:red
)

yyy=[0.201,0.108,0.143,0.18,0.228,0.293,0.362,0.439,0.495,0.586,0.66,0.7,0.745,0.81,0.818,0.875,0.9,0.929,0.927,0.926,0.942,0.943,0.95,0.954]

plot!(x,yyy,
seriestype=:scatter;
xticks=(1:25),
    ylim=(0,1.05),
    titel="proportion of full Galois group",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=2ln(n)/n",
    legend=false,
    color=:blue
)
