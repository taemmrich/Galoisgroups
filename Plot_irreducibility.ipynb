# %%
using Pkg
Pkg.add("Plots")

# %%
using Plots

#p=1/2, k=1000
x=2:25
y=[0.228,0.183,0.16,0.2,0.244,0.351,0.447,0.56,0.652,0.753,0.815,0.877,0.921,0.956,0.966,0.977,0.988,0.996,1.0,0.999,0.999,0.999,1,1]

plot(x,y,
    seriestype=:scatter;
    xticks=(1:25),
    ylim=(0,1.05),
    titel="probability of random matrices",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=1/2",
    legend=false,
    color=:black
)

#p=4/n, k=1000

yy=[0,0,0,0.08,0.26,0.37,0.422,0.494,0.537,0.579,0.593,0.571,0.598,0.579,0.575,0.594,0.579,0.584,0.558,0.568,0.542,0.554,0.571,0.542]
plot!(x,yy,
    seriestype=:scatter;
    xticks=(1:25),
    ylim=(0,1.05),
    titel="probability of random matrices",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=4/n",
    legend=false,
    color=:red
)

yyy=[0.3,0.162,0.154,0.212,0.27,0.363,0.439,0.54,0.625,0.68,0.739,0.814,0.819,0.866,0.912,0.921,0.937,0.951,0.957,0.962,0.965,0.]

plot!(x,yyy,
seriestype=:scatter;
xticks=(1:25),
    ylim=(0,1.05),
    titel="proportion of full Galois group",
    #xlabel="Size of matrix",
    #ylabel="proportion of matrices with full Galois group",
    #label="p=2ln(n)/n",
    legend=false,
    color=:blue
)
